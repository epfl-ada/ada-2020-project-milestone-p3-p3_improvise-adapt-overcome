# %%
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as smf

# %%
df_well_being_raw = pd.read_excel("london-ward-well-being-probability-scores.xls", sheet_name="Scores")
df_grocery_raw = pd.read_csv('year_osward_grocery.csv')

# %%
df_well = df_well_being_raw[["Unnamed: 1", "Subjective well-being average score.4"]]
df_well.columns = ['area_id', 'well_being']
df_well = df_well.drop(0)
df_well = df_well.dropna()

# %%
#df_grocery = df_grocery_raw[["area_id", "fat", "saturate", "salt", "sugar", "protein", "carb", "fibre", "alcohol"]]
df_grocery = df_grocery_raw[["area_id", "fat", "saturate", "salt", "sugar", "protein", "carb", "fibre", "alcohol", "energy_fat", "energy_saturate","energy_sugar", 
                             "energy_protein", "energy_carb", "energy_fibre", "energy_alcohol", "energy_tot", "h_nutrients_calories_norm",
                            'f_beer', 'f_dairy', 'f_eggs', 'f_fats_oils', 'f_fish', 'f_fruit_veg', 'f_grains', 'f_meat_red', 'f_poultry',
                             'f_readymade', 'f_sauces', 'f_soft_drinks', 'f_spirits', 'f_sweets', 'f_tea_coffee', 'f_water', 'f_wine']]

nutrients = ["fat", "saturate", "sugar", "protein", "carb", "fibre", "alcohol"]
df_grocery_percentage = df_grocery.copy()
for i, nutrient in enumerate (nutrients):
    df_grocery_percentage["percentage_%s"%nutrient] = df_grocery_percentage["energy_%s"%nutrient] *100 / df_grocery["energy_tot"]

# %%
df_grocery_percentage
# Out:
#        area_id       fat  saturate      salt      sugar   protein       carb  \
# 0    E05000026  9.488797  3.693721  0.583240  10.966213  4.977560  19.381951
# 1    E05000027  9.733634  3.565913  0.568184  10.514427  5.211694  18.950348
# 2    E05000028  9.216310  3.613582  0.610536  10.690272  5.192412  19.662048
# 3    E05000029  9.700137  3.961264  0.533180  12.938606  4.718184  20.084734
# 4    E05000030  9.381808  3.614663  0.566784  11.332898  5.307003  19.581403
# ..         ...       ...       ...       ...        ...       ...        ...
# 633  E05011485  9.059381  3.504138  0.543892  11.155665  5.059010  19.018689
# 634  E05011486  8.819808  3.367769  0.586726  10.804966  5.174936  19.238456
# 635  E05011487  9.156464  3.434680  0.554677  11.401595  5.132303  19.398455
# 636  E05011488  9.557516  3.706401  0.582808  12.093208  5.119245  20.472076
# 637  E05011489  8.930276  3.571823  0.556489  10.962854  5.245978  18.729160
#
#         fibre   alcohol  energy_fat  ...  f_tea_coffee   f_water    f_wine  \
# 0    1.564721  0.198172   85.399176  ...      0.005945  0.042942  0.007917
# 1    1.581960  0.209917   87.602703  ...      0.005572  0.041258  0.007355
# 2    1.572323  0.225425   82.946787  ...      0.006076  0.043609  0.009281
# 3    1.550344  0.200380   87.301229  ...      0.006578  0.046902  0.007344
# 4    1.607947  0.168952   84.436271  ...      0.006638  0.039688  0.009738
# ..        ...       ...         ...  ...           ...       ...       ...
# 633  1.556461  0.251503   81.534433  ...      0.006308  0.039785  0.018416
# 634  1.574568  0.234103   79.378269  ...      0.006518  0.045984  0.015791
# 635  1.665961  0.230386   82.408176  ...      0.006296  0.040283  0.012097
# 636  1.606728  0.177276   86.017640  ...      0.007404  0.048004  0.008467
# 637  1.519979  0.210374   80.372487  ...      0.006232  0.036314  0.015475
#
#      percentage_fat  percentage_saturate  percentage_sugar  \
# 0         45.640000            17.766364         23.442754
# 1         46.439549            17.013110         22.295443
# 2         44.389378            17.404437         22.883805
# 3         45.759214            18.686781         27.127245
# 4         44.880395            17.291712         24.095093
# ..              ...                  ...               ...
# 633       44.678745            17.281586         24.452054
# 634       43.711512            16.690874         23.800036
# 635       44.489578            16.688481         24.621447
# 636       44.667084            17.321877         25.118957
# 637       44.503255            17.799868         24.281081
#
#      percentage_protein  percentage_carb  percentage_fibre  percentage_alcohol
# 0             10.640657        41.433292          1.544686            0.741364
# 1             11.051200        40.183491          1.546797            0.778963
# 2             11.114978        42.088964          1.562220            0.844460
# 3              9.892203        42.109906          1.503467            0.735209
# 4             11.283322        41.632398          1.575264            0.628621
# ..                  ...              ...               ...                 ...
# 633           11.088822        41.686985          1.580729            0.964718
# 634           11.398800        42.376434          1.610854            0.902399
# 635           11.083074        41.890458          1.666242            0.870648
# 636           10.633250        42.522809          1.532470            0.644387
# 637           11.619056        41.482285          1.579995            0.815408
#
# [638 rows x 42 columns]

# %%
df = df_well.merge(df_grocery_percentage, on='area_id')

# %%
df
# Out:
#        area_id  well_being       fat  saturate      salt      sugar   protein  \
# 0    E05000026    6.118185  9.488797  3.693721  0.583240  10.966213  4.977560
# 1    E05000027   -4.726708  9.733634  3.565913  0.568184  10.514427  5.211694
# 2    E05000028   -4.813479  9.216310  3.613582  0.610536  10.690272  5.192412
# 3    E05000029   -4.813479  9.700137  3.961264  0.533180  12.938606  4.718184
# 4    E05000030   -4.726708  9.381808  3.614663  0.566784  11.332898  5.307003
# ..         ...         ...       ...       ...       ...        ...       ...
# 478  E05000645   16.097385  9.011954  3.558849  0.584727   9.403091  5.499603
# 479  E05000646   16.097385  8.810350  3.379945  0.604999   9.350598  5.584789
# 480  E05000647   16.097385  8.642757  3.398100  0.584833   9.446028  5.321004
# 481  E05000648   15.507184  8.919674  3.512147  0.549463   9.623928  5.259262
# 482  E05000649   16.097385  9.154919  3.642411  0.560853  10.170574  5.328714
#
#           carb     fibre   alcohol  ...  f_tea_coffee   f_water    f_wine  \
# 0    19.381951  1.564721  0.198172  ...      0.005945  0.042942  0.007917
# 1    18.950348  1.581960  0.209917  ...      0.005572  0.041258  0.007355
# 2    19.662048  1.572323  0.225425  ...      0.006076  0.043609  0.009281
# 3    20.084734  1.550344  0.200380  ...      0.006578  0.046902  0.007344
# 4    19.581403  1.607947  0.168952  ...      0.006638  0.039688  0.009738
# ..         ...       ...       ...  ...           ...       ...       ...
# 478  16.729870  1.609476  0.292334  ...      0.006161  0.026018  0.021485
# 479  17.240961  1.640990  0.209072  ...      0.005728  0.030805  0.014232
# 480  17.579308  1.680360  0.299310  ...      0.004823  0.026675  0.022156
# 481  17.940815  1.611090  0.195706  ...      0.006401  0.037393  0.015903
# 482  17.765000  1.665483  0.217665  ...      0.007219  0.030233  0.013374
#
#      percentage_fat  percentage_saturate  percentage_sugar  \
# 0         45.640000            17.766364         23.442754
# 1         46.439549            17.013110         22.295443
# 2         44.389378            17.404437         22.883805
# 3         45.759214            18.686781         27.127245
# 4         44.880395            17.291712         24.095093
# ..              ...                  ...               ...
# 478       46.319170            18.291587         21.479785
# 479       45.269606            17.366936         21.353566
# 480       44.537008            17.510757         21.633932
# 481       45.227374            17.808405         21.688136
# 482       45.911837            18.266657         22.669041
#
#      percentage_protein  percentage_carb  percentage_fibre  percentage_alcohol
# 0             10.640657        41.433292          1.544686            0.741364
# 1             11.051200        40.183491          1.546797            0.778963
# 2             11.114978        42.088964          1.562220            0.844460
# 3              9.892203        42.109906          1.503467            0.735209
# 4             11.283322        41.632398          1.575264            0.628621
# ..                  ...              ...               ...                 ...
# 478           12.562921        38.216582          1.732698            1.168630
# 479           12.753748        39.372456          1.768656            0.835535
# 480           12.186522        40.261319          1.815528            1.199623
# 481           11.852083        40.430772          1.717957            0.771814
# 482           11.877090        39.596143          1.765918            0.849012
#
# [483 rows x 43 columns]

# %%
spearman_nutrients = {}
spearman_weight = {}
spearman_energy = {}

for nutrient in nutrients:
    spearman_nutrients[nutrient] = stats.spearmanr(df["percentage_%s"%nutrient],df['well_being'])
    spearman_weight[nutrient] = stats.spearmanr(df["%s"%nutrient],df['well_being'])
    spearman_energy[nutrient] = stats.spearmanr(df["energy_%s"%nutrient],df['well_being'])
    
spearman_entropy = stats.spearmanr(df["h_nutrients_calories_norm"],df['well_being'])

# %%
# Fit linear regression model to nutrients
mod = smf.ols(formula='well_being ~  fat + sugar + alcohol + carb + saturate + protein + fibre', data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             well_being   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     1.467
# Date:                Fri, 11 Dec 2020   Prob (F-statistic):              0.177
# Time:                        11:57:21   Log-Likelihood:                -1784.5
# No. Observations:                 483   AIC:                             3585.
# Df Residuals:                     475   BIC:                             3618.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -7.3516     19.021     -0.387      0.699     -44.727      30.024
# fat            6.4024      3.314      1.932      0.054      -0.110      12.915
# sugar          1.5683      1.145      1.369      0.172      -0.682       3.819
# alcohol      -11.1800     10.946     -1.021      0.308     -32.688      10.328
# carb          -1.0656      0.725     -1.470      0.142      -2.490       0.359
# saturate     -12.6681      6.308     -2.008      0.045     -25.062      -0.274
# protein        3.7130      2.759      1.346      0.179      -1.709       9.135
# fibre        -12.0055      6.961     -1.725      0.085     -25.684       1.673
# ==============================================================================
# Omnibus:                        8.178   Durbin-Watson:                   0.657
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):                8.399
# Skew:                           0.311   Prob(JB):                       0.0150
# Kurtosis:                       2.829   Cond. No.                     1.05e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.05e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Fit logistic regression model to foods
mod = smf.ols(formula='well_being ~  f_beer + f_dairy + f_eggs + f_fats_oils+f_fish+f_fruit_veg+f_grains+f_meat_red+f_poultry+f_readymade + f_sauces+f_soft_drinks+f_spirits+f_sweets+f_tea_coffee+f_water+f_wine', data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             well_being   R-squared:                       0.101
# Model:                            OLS   Adj. R-squared:                  0.070
# Method:                 Least Squares   F-statistic:                     3.257
# Date:                Fri, 11 Dec 2020   Prob (F-statistic):           2.18e-05
# Time:                        11:57:23   Log-Likelihood:                -1764.0
# No. Observations:                 483   AIC:                             3562.
# Df Residuals:                     466   BIC:                             3633.
# Df Model:                          16
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       -28.1847     42.416     -0.664      0.507    -111.535      55.165
# f_beer           16.3294    145.865      0.112      0.911    -270.305     302.964
# f_dairy         132.5198     68.507      1.934      0.054      -2.101     267.141
# f_eggs          378.6625    297.312      1.274      0.203    -205.576     962.901
# f_fats_oils    -215.4834    175.410     -1.228      0.220    -560.177     129.210
# f_fish          698.5848    197.115      3.544      0.000     311.241    1085.929
# f_fruit_veg     -34.3698     54.014     -0.636      0.525    -140.511      71.771
# f_grains        -75.8303     76.381     -0.993      0.321    -225.924      74.264
# f_meat_red      129.2989    137.916      0.938      0.349    -141.716     400.313
# f_poultry      -596.9624    249.037     -2.397      0.017   -1086.337    -107.588
# f_readymade     220.7514     78.280      2.820      0.005      66.925     374.577
# f_sauces       -235.4353    274.287     -0.858      0.391    -774.428     303.558
# f_soft_drinks  -171.4691    123.076     -1.393      0.164    -413.322      70.384
# f_spirits      -517.1459    492.396     -1.050      0.294   -1484.736     450.445
# f_sweets         77.2958     64.120      1.205      0.229     -48.705     203.297
# f_tea_coffee   -323.2926    463.027     -0.698      0.485   -1233.171     586.586
# f_water         381.0367    138.756      2.746      0.006     108.373     653.701
# f_wine          107.3249    127.495      0.842      0.400    -143.212     357.862
# ==============================================================================
# Omnibus:                        6.508   Durbin-Watson:                   0.805
# Prob(Omnibus):                  0.039   Jarque-Bera (JB):                6.663
# Skew:                           0.279   Prob(JB):                       0.0357
# Kurtosis:                       2.856   Cond. No.                     1.46e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.59e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
### Let's build a healhty diet according to https://en.wikipedia.org/wiki/Healthy_diet

foods = dict(zip(["fruit_veg", "grains", "dairy", "meat_red", "poultry", "eggs", "fish"], [4.5, 0.75, 3, 1.5/7, 1.25/7, 0.375/7, 1/7]))
sum_values = sum(foods.values())

for food in foods.keys():
    foods[food] = foods[food]/sum_values

# %%
foods
# Out:
# {'fruit_veg': 0.5090909090909091,
#  'grains': 0.08484848484848485,
#  'dairy': 0.3393939393939394,
#  'meat_red': 0.024242424242424242,
#  'poultry': 0.020202020202020204,
#  'eggs': 0.006060606060606061,
#  'fish': 0.01616161616161616}

# %%
df_healthy = df.copy()
df_healthy.loc[:,"score"] =0
for food in foods:
    df_healthy["score"] += (df_healthy["f_%s"%food] - foods[food])**2

# %%
df_healthy
# Out:
#        area_id  well_being       fat  saturate      salt      sugar   protein  \
# 0    E05000026    6.118185  9.488797  3.693721  0.583240  10.966213  4.977560
# 1    E05000027   -4.726708  9.733634  3.565913  0.568184  10.514427  5.211694
# 2    E05000028   -4.813479  9.216310  3.613582  0.610536  10.690272  5.192412
# 3    E05000029   -4.813479  9.700137  3.961264  0.533180  12.938606  4.718184
# 4    E05000030   -4.726708  9.381808  3.614663  0.566784  11.332898  5.307003
# ..         ...         ...       ...       ...       ...        ...       ...
# 478  E05000645   16.097385  9.011954  3.558849  0.584727   9.403091  5.499603
# 479  E05000646   16.097385  8.810350  3.379945  0.604999   9.350598  5.584789
# 480  E05000647   16.097385  8.642757  3.398100  0.584833   9.446028  5.321004
# 481  E05000648   15.507184  8.919674  3.512147  0.549463   9.623928  5.259262
# 482  E05000649   16.097385  9.154919  3.642411  0.560853  10.170574  5.328714
#
#           carb     fibre   alcohol  ...   f_water    f_wine  percentage_fat  \
# 0    19.381951  1.564721  0.198172  ...  0.042942  0.007917       45.640000
# 1    18.950348  1.581960  0.209917  ...  0.041258  0.007355       46.439549
# 2    19.662048  1.572323  0.225425  ...  0.043609  0.009281       44.389378
# 3    20.084734  1.550344  0.200380  ...  0.046902  0.007344       45.759214
# 4    19.581403  1.607947  0.168952  ...  0.039688  0.009738       44.880395
# ..         ...       ...       ...  ...       ...       ...             ...
# 478  16.729870  1.609476  0.292334  ...  0.026018  0.021485       46.319170
# 479  17.240961  1.640990  0.209072  ...  0.030805  0.014232       45.269606
# 480  17.579308  1.680360  0.299310  ...  0.026675  0.022156       44.537008
# 481  17.940815  1.611090  0.195706  ...  0.037393  0.015903       45.227374
# 482  17.765000  1.665483  0.217665  ...  0.030233  0.013374       45.911837
#
#      percentage_saturate  percentage_sugar  percentage_protein  \
# 0              17.766364         23.442754           10.640657
# 1              17.013110         22.295443           11.051200
# 2              17.404437         22.883805           11.114978
# 3              18.686781         27.127245            9.892203
# 4              17.291712         24.095093           11.283322
# ..                   ...               ...                 ...
# 478            18.291587         21.479785           12.562921
# 479            17.366936         21.353566           12.753748
# 480            17.510757         21.633932           12.186522
# 481            17.808405         21.688136           11.852083
# 482            18.266657         22.669041           11.877090
#
#      percentage_carb  percentage_fibre  percentage_alcohol     score
# 0          41.433292          1.544686            0.741364  0.125700
# 1          40.183491          1.546797            0.778963  0.130958
# 2          42.088964          1.562220            0.844460  0.138758
# 3          42.109906          1.503467            0.735209  0.152978
# 4          41.632398          1.575264            0.628621  0.139938
# ..               ...               ...                 ...       ...
# 478        38.216582          1.732698            1.168630  0.102913
# 479        39.372456          1.768656            0.835535  0.102567
# 480        40.261319          1.815528            1.199623  0.105918
# 481        40.430772          1.717957            0.771814  0.097920
# 482        39.596143          1.765918            0.849012  0.093204
#
# [483 rows x 44 columns]

# %%
stats.spearmanr(df_healthy["score"],df_healthy['well_being'])
# Out:
# SpearmanrResult(correlation=0.09502979534896164, pvalue=0.036814974492699666)
